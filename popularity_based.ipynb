# %% [markdown]
# <a href="https://colab.research.google.com/github/riyalguha/Weighted_avg_recc_system/blob/main/popularity_based.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data_df = pd.read_csv("chefmozcuisine.csv")

# %%
rating_df = pd.read_csv("rating_final.csv")

# %%
data_df.head()
# Out:
#    placeID        Rcuisine
# 0   135110         Spanish
# 1   135109         Italian
# 2   135107  Latin_American
# 3   135106         Mexican
# 4   135105       Fast_Food

# %%
rating_df.head()
# Out:
#   userID  placeID  rating  food_rating  service_rating
# 0  U1077   135085       2            2               2
# 1  U1077   135038       2            2               1
# 2  U1077   132825       2            2               2
# 3  U1077   135060       1            2               2
# 4  U1068   135104       1            1               2

# %%
rating_count = pd.DataFrame(rating_df.groupby('placeID')['rating'].count())

# %%
rating_count.head()
# Out:
#          rating
# placeID
# 132560        4
# 132561        4
# 132564        4
# 132572       15
# 132583        4

# %%
rating_count.sort_values('rating',ascending = False)
# Out:
#          rating
# placeID
# 135085       36
# 132825       32
# 135032       28
# 135052       25
# 132834       25
# ...         ...
# 132766        3
# 132717        3
# 135011        3
# 132668        3
# 135016        3
#
# [130 rows x 1 columns]

# %%
rating_count.head()
# Out:
#          rating
# placeID
# 132560        4
# 132561        4
# 132564        4
# 132572       15
# 132583        4

# %%
most_rated_places = pd.DataFrame([135085, 132825, 135032, 135052, 132834] , index = np.arange(5), columns = ['placeID'])

# %%
most_rated_places.head()
# Out:
#    placeID
# 0   135085
# 1   132825
# 2   135032
# 3   135052
# 4   132834

# %%
summary = pd.merge(most_rated_places, data_df, on='placeID')

# %%
summary
# Out:
#    placeID         Rcuisine
# 0   135085        Fast_Food
# 1   132825          Mexican
# 2   135032        Cafeteria
# 3   135032     Contemporary
# 4   135052              Bar
# 5   135052  Bar_Pub_Brewery
# 6   132834          Mexican

# %%
data_df['Rcuisine'].describe()
# Out:
# count         916
# unique         59
# top       Mexican
# freq          239
# Name: Rcuisine, dtype: object
